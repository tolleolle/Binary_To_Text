# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
##### import project related moduls ####
current_file = Path.cwd() # cwd = path/*.ipynb - does not work in .py files.
print(f"current_file = {current_file}")
project_root = current_file.parent.parent
print(f"project_root = {project_root}")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import utils.file_utils as fu   
from utils.terminal_styler import TerminalColours as tc
from spf2_converter import BGCorrector

# %matplotlib QtAgg

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %% [markdown]
# ### correction for forlder 2026_09_03_spectra_10Pa

# %% [markdown]
# #### get folder path

# %%
## correction for forlder 2026_09_03_spectra_10Pa
# folder_path = None
folder_path = Path(r"C:\Andrei\DATA\VINETA_75\2026_09_03_spectra_10Pa\txt")
files = fu.list_files_in_folder(folder_path=folder_path)
print(files[0].parent)
for f in files:
    print(f.name)

# %% [markdown]
# #### set spectral and bg files

# %%
spec_files_names = ["02sp1p3kW_10s.txt", "03sp1p3kW_10s.txt", 
              "04sp1p3kW_10s.txt", "05a2p0kW_10s.txt", 
              "06a2p0kW_10s.txt"]
bg_file_name = "abg_10s_16-52.txt"
corr = BGCorrector()
corr.bg_fpath = folder_path / bg_file_name
corr.data_dir = folder_path

print(corr.bg_fpath)

# %% [markdown]
# #### correction

# %%
for name in spec_files_names:
    fpath = folder_path / name
    corr.spec_fpath = fpath
    corr.correct_file(tx_A=10, tx_B=10)

# %% [markdown]
# #### check bg files

# %%
dfs = []
fpath = folder_path / "bg_10s_15-37.txt"
df1537 = corr.read_file(fpath=fpath)
dfs.append(df1537)
fpath = folder_path / "bg_10s_15-48.txt"
df1548 = corr.read_file(fpath=fpath)
dfs.append(df1548)
fpath = folder_path / "bg_10s_16-14.txt"
df1614 = corr.read_file(fpath=fpath)
dfs.append(df1614)
fpath = folder_path / "abg_10s_16-52.txt"
dfa = corr.read_file(fpath=fpath)
dfs.append(dfa)

len(dfs)
dfa.head(10)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 5), dpi=100)
for df in dfs:
    ax1.plot(df["wavelength1"], df["intensity1"],  alpha=0.8)
    ax2.plot(df["wavelength2"], df["intensity2"],  alpha=0.8)

# %% [markdown]
# ### correction for forlder 2026_09_04_spectra_10Pa

# %% [markdown]
# #### get folder path

# %%
folder_path = Path(r"C:\Andrei\DATA\VINETA_75\2026_09_04_spectra_10Pa\txt")
files = fu.list_files_in_folder(folder_path=folder_path)
print(files[0].parent)
for f in files:
    print(f.name)

# %%
# %reload_ext autoreload

# %% [markdown]
# #### set spectral and bg files

# %%
## seporate bg and other files
files = fu.list_files_in_folder(folder_path=folder_path)
bg_files = []
spec_files = []
for file in files:
    if file.name.endswith('_bg.txt'):
        bg_files.append(file)
    else:
        spec_files.append(file)

for f in bg_files:
    print(f.name)

# %%
## get spectral files with bg piar
working_files = []
for f in spec_files:
    f_bg = f.parent / f"{f.stem}_bg.txt"
    if f_bg in bg_files:
        print(f"{tc.GREEN} {f.stem} {tc.RESET}")
        working_files.append(f)
    else:
        print(f"{tc.RED}{f.stem} {tc.RESET}")

# %%
# %reload_ext autoreload

# %%
corr = BGCorrector()
corr.data_dir = working_files[0].parent
for f in working_files:
    sp_name = f.name.split('_')
    corr.fname_parts = sp_name
    corr.spec_fpath = f
    corr.bg_fpath = f.parent / f"{f.stem}_bg.txt"

    # print(corr.fname_parts[-1])
    if corr.fname_parts[-1].endswith("s.txt"):
        tx = int(corr.fname_parts[-1].split('.')[0][0])
    else: 
        tx = 10
    print(f"{tx=}")
    corr.correct_file(tx_A=tx, tx_B=tx)


    print()

# %% [markdown]
# ### correction for other files

# %%
corr = BGCorrector()

# %%
# %reload_ext autoreload

# %%
# corr.select_folder()
corr.get_spec_bg_pairs().correct_folder()

# %% [markdown]
# ### check file 11_P0p400kW_a300ms_b2000msQ_bg
# folder: 'C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt'

# %%
fpath = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/11_P0p400kW_a300ms_b2000ms_bg.txt')
fpath2 = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/10_P0p600kW_a300msx50_b2000msx10_bg.txt')
dfQ = corr.read_file(fpath=fpath)
df2 = corr.read_file(fpath=fpath2)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 5), dpi=100)
ax1.plot(dfQ["wavelength1"], dfQ["intensity1"],  alpha=0.8)
ax1.plot(df2["wavelength1"], df2["intensity1"],  alpha=0.8)
ax2.plot(dfQ["wavelength2"], dfQ["intensity2"],  alpha=0.8)
ax2.plot(df2["wavelength2"], df2["intensity2"],  alpha=0.8)

## the file is as excpected, mark Q deleted

# %% [markdown]
# ### construct bg file for
# 12_P0p670kW_a500ms_b10000ms.txt
# 12_P0p670kW_a500msx50_b10000msx5.txt

# %%
fpath = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/12_P0p670kW_a500ms_b10000ms.txt')
fpath2 = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/10_P0p600kW_a300msx50_b2000msx10_bg.txt')
dfQ = corr.read_file(fpath=fpath)
df2 = corr.read_file(fpath=fpath2)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 5), dpi=100)
ax1.plot(dfQ["wavelength1"], dfQ["intensity1"],  alpha=0.8)
ax1.plot(df2["wavelength1"], df2["intensity1"]*1.5,  alpha=0.8)
ax2.plot(dfQ["wavelength2"], dfQ["intensity2"],  alpha=0.8)
ax2.plot(df2["wavelength2"], df2["intensity2"]*3 - 0.005,  alpha=0.8)

# %% [markdown]
# #### save new bg file

# %%
fnew = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/12_P0p670kW_a500ms_b10000ms_bg.txt')
df_new = df2.copy()
df_new["intensity1"] = df_new["intensity1"]*1.5
df_new["intensity2"] = df_new["intensity2"]*3 - 0.005
df_new.to_csv(fnew, sep="\t", index=False)

# %% [markdown]
# #### check new bg file

# %%
fQ = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/12_P0p670kW_a500ms_b10000ms.txt')
fnew = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/12_P0p670kW_a500ms_b10000ms_bg.txt')

dfQ = corr.read_file(fpath=fQ)
df_new = corr.read_file(fpath=fnew)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 5), dpi=100)
ax1.plot(dfQ["wavelength1"], dfQ["intensity1"],  alpha=0.8)
ax1.plot(df_new["wavelength1"], df_new["intensity1"],  alpha=0.8)
ax2.plot(dfQ["wavelength2"], dfQ["intensity2"],  alpha=0.8)
ax2.plot(df_new["wavelength2"], df_new["intensity2"],  alpha=0.8)

# %% [markdown]
# #### check that this bg file is siutable for the second file

# %%
fnew = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/12_P0p670kW_a500ms_b10000ms_bg.txt')
fQ = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/12_P0p670kW_a500msx50_b10000msx5.txt')

dfQ = corr.read_file(fpath=fQ)
df_new = corr.read_file(fpath=fnew)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 5), dpi=100)
ax1.plot(dfQ["wavelength1"], dfQ["intensity1"],  alpha=0.8)
ax1.plot(df_new["wavelength1"], df_new["intensity1"],  alpha=0.8)
ax2.plot(dfQ["wavelength2"], dfQ["intensity2"],  alpha=0.8)
ax2.plot(df_new["wavelength2"], df_new["intensity2"],  alpha=0.8)

# %% [markdown]
# ### substract bg for gelb file

# %%
fpath_spec = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/P0p540kW_a300ms_gelb.txt')
fpath_bg = Path('C:/Andrei/DATA/VINETA_75/2026_09_11_spec/p6p5Pa/txt/11_P0p400kW_a300ms_b2000ms_bg.txt')

corr.spec_fpath = fpath_spec
corr.bg_fpath = fpath_bg
## correct_folder() takes tx in ms, but correct_file in seconds !!!
corr.correct_file(tx_A=0.3, tx_B=2)
